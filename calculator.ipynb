# %%
1+3+5
# Out:
# 9

# %%
20.5+3+5+5.6
# Out:
# 34.1

# %%
5+(8*7)
# Out:
# 61

# %%
4/7
# Out:
# 0.5714285714285714

# %%
4//7
# Out:
# 0

# %% [markdown]
# 20%4

# %%
20%4
# Out:
# 0

# %%
13%4
# Out:
# 1

# %%
"Hello"+"World"
# Out:
# 'HelloWorld'

# %%
"Hello"+" World"
# Out:
# 'Hello World'

# %%
"Hello"+" World"+" 3"
# Out:
# 'Hello World 3'

# %%
"Hello"+' Python'
# Out:
# 'Hello Python'

# %%
3*'stone'+'age'
# Out:
# 'stonestonestoneage'

# %%
a=2
b=3
c=4
d=5
e=10
output=((a*b)+(a+b+c)*2)/c
print(output)
# Out:
# 6.0
